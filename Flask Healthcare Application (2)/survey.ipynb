# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV file into DataFrame
df = pd.read_csv('users_data.csv')

# Visualization 1: Ages with the highest income
plt.figure(figsize=(10, 5))
df.groupby('Age')['Total Income'].max().plot(kind='bar')
plt.title('Ages with the Highest Income')
plt.xlabel('Age')
plt.ylabel('Total Income')
plt.savefig('age_income.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 20
#      18 for category in expense_categories:
#      19     plt.figure(figsize=(10, 5))
# ---> 20     df.groupby('Gender')[category].sum().plot(kind='bar')
#      21     plt.title(f'Gender Distribution in {category}')
#      22     plt.xlabel('Gender')
#
# File c:\Users\NAIRAMETRICS\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\NAIRAMETRICS\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\NAIRAMETRICS\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
#     450     self._args_adjust()
# --> 451     self._compute_plot_data()
#     452     self._setup_subplots()
#     453     self._make_plot()
#
# File c:\Users\NAIRAMETRICS\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:636, in MPLPlot._compute_plot_data(self)
#     634 # no non-numeric frames or series allowed
#     635 if is_empty:
# --> 636     raise TypeError("no numeric data to plot")
#     638 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
